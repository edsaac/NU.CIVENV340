# %%
import hydrofunctions as hf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
spanish_creek = hf.NWIS(site="11402000", service="iv", period="P365D")
# Out:
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11402000&period=P365D
# /home/edsaac/venv/lib/python3.10/site-packages/hydrofunctions/hydrofunctions.py:629: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   if not DF.index.is_monotonic:

# %%
spanish_creek
# Out:
# USGS:11402000: SPANISH C AB BLACKHAWK C AT KEDDIE CA
#     00060: <15 * Minutes>  Discharge, cubic feet per second
#     00065: <15 * Minutes>  Gage height, feet
# Start: 2022-05-15 16:00:00+00:00
# End:   2023-05-15 15:30:00+00:00

# %%
spanish_creek.df().columns
# Out:
# Index(['USGS:11402000:00060:00000', 'USGS:11402000:00060:00000_qualifiers',
#        'USGS:11402000:00065:00000', 'USGS:11402000:00065:00000_qualifiers'],
#       dtype='object')

# %%
Q = spanish_creek.df("discharge")
y = spanish_creek.df("stage")

# %%
fig, ax = plt.subplots()
ax.plot(Q["USGS:11402000:00060:00000"], y["USGS:11402000:00065:00000"])
plt.show()
